# %%
def sama_semua(text):
    for i in text:
        if i != text[0]:
            return False
    return True 
text = (40, 40, 40, 40)
print(sama_semua(text))
# Out:
# True

# %%
data_pribadi = (' Michella Tesalonika Putri Pramono', '71251228', 'Pati, Jawa Tengah')
print('NIM:', data_pribadi[1])
print('Nama:', data_pribadi[0])
print(f'Alamat:{data_pribadi[2]}\n')

tuple_NIM = tuple(data_pribadi[1])
print(f'NIM : {tuple_NIM}\n')

nama_awal = data_pribadi[0].split()[0]
nama = nama_awal[1:]
nama_awal_tuple = tuple(nama)
print(f'Nama: {nama_awal_tuple}\n')
nama_balik = tuple(data_pribadi[0].split()[::-1])
print('nama balik: ',nama_balik)
# Out:
# NIM: 71251228
# Nama:  Michella Tesalonika Putri Pramono
# Alamat:Pati, Jawa Tengah
#
# NIM : ('7', '1', '2', '5', '1', '2', '2', '8')
#
# Nama: ('i', 'c', 'h', 'e', 'l', 'l', 'a')
#
# nama balik:  ('Pramono', 'Putri', 'Tesalonika', 'Michella')

# %%
namefile = input('Masukkan nama file.txt:')
try:
    with open (nama_file, 'r') as filr:
        jam = {}
        for i in file:
            if i.startwith('From'):
                time = i.split()[5].split()[0]
                jam[time] = jam.get(waktu,0)+1

        for k in sorted(jam):
            print(k, jam[k])
except FileNotError:
    print('File tidak ditemukan')
