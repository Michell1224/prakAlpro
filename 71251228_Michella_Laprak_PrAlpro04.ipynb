# %%
try:
    suhu = int(input("Masukkan suhu tubuh: "))
    if suhu >=38:
        print("Anda demam")
    else:
        print("Anda tidak demam")
except:
    print("Anda tidak memasukkan angka")
# Out:
# Masukkan suhu tubuh:  26
# Anda tidak demam

# %%
try:
    suhu = int(input("Masukkan suhu tubuh: "))
    if suhu >=38:
        print("Anda demam")
    else:
        print("Anda tidak demam")
except:
    print("Anda tidak memasukkan angka")
# Out:
# Masukkan suhu tubuh:  lelw
# Anda tidak memasukkan angka

# %%
try:
    bilangan = int(input("Masukkan suatu bilangan: "))
    if bilangan >0:
        print("positif")
    elif bilangan < 0:
        print("Negatif")
    elif bilangan == 0:
        print("Nol")
except:
    print("Anda tidak memasukkan angka")
# Out:
# Masukkan suatu bilangan:  24
# positif

# %%
try:
    bilangan = int(input("Masukkan suatu bilangan: "))
    if bilangan >0:
        print("positif")
    elif bilangan < 0:
        print("Negatif")
    elif bilangan == 0:
        print("Nol")
except:
    print("Anda tidak memasukkan angka")
# Out:
# Masukkan suatu bilangan:  lelw
# Anda tidak memasukkan angka

# %%
try:
    a = int(input("Masukkan bilangan pertama: "))
    b = int(input("Masukkan bilangan kedua: "))
    c = int(input("Masukkan bilangan keiga: "))
    # secara berurutan tulis kriteris untuk a, b, c
    if a>b and a>c:
        print("terbesar: ",a)
    elif b>a and b>c: 
        print("terbesar: ",b)
    elif c>a and c>b:
        print("terbesar: ",c)
except:
    print("Anda tidak memasukkan angka")
# Out:
# Masukkan bilangan pertama:  5
# Masukkan bilangan kedua:  4
# Masukkan bilangan keiga:  9
# terbesar:  9

# %%
try:
    a = int(input("Masukkan bilangan pertama: "))
    b = int(input("Masukkan bilangan kedua: "))
    c = int(input("Masukkan bilangan keiga: "))
    # secara berurutan tulis kriteris untuk a, b, c
    if a>b and a>c:
        print("terbesar: ",a)
    elif b>a and b>c: 
        print("terbesar: ",b)
    elif c>a and c>b:
        print("terbesar: ",c)
except:
    print("Anda tidak memasukkan angka")
# Out:
# Masukkan bilangan pertama:  lelw
# Anda tidak memasukkan angka

# %%
bilangan = int(input("Masukkan suatu bilangan: "))
print("Positif" if bilangan > 0 else "Negatif" if bilangan < 0 else "Nol")
# Out:
# Masukkan suatu bilangan:  -24
# Negatif

# %%
try:
    bulan = int(input("Masukkan angka bulan: "))
    jumlah_hari = {1: 31, 2: 29, 3: 31, 4: 30, 5: 31, 6: 30, 7: 31, 8: 31, 9: 30, 10: 31, 11: 30, 12: 31}

    if 1<= bulan <=12:
        print("Jumlah hari adalah", jumlah_hari[bulan])
    else:
        print("bulan tidak valid")
except:
    print("Anda tidak memasukkan angka")
# Out:
# Masukkan angka bulan:  12
# Jumlah hari adalah 31

# %%
try:
    sisi_1 = int(input("Masukkan sisi 1: "))
    sisi_2 = int(input("Masukkan sisi 2: "))
    sisi_3 = int(input("Masukkan sisi 3: "))
    if sisi_1 == sisi_2 == sisi_3 or sisi_2 == sisi_1 == sisi_3 or sisi_3 == sisi_2 == sisi_1:
        print("3 sisi sama")
    elif sisi_1 == sisi_2 or sisi_1 == sisi_3 or sisi_2 == sisi_3:
        print("2 sisi sama")
    else:
        print("Tidak ada yang sama")
except:
    print("Anda tidak memasukkan angka")
# Out:
# Masukkan sisi 1:  2
# Masukkan sisi 2:  2
# Masukkan sisi 3:  2
# 3 sisi sama
